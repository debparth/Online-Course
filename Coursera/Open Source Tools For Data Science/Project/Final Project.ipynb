# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# ### Parth Mehta

# %% [markdown]
#  - Python Programmer & IT Student

# %% [markdown]
# _I am interested in data science because I like Computer Vision and want to contribute myself to that field_

# %% [markdown]
# ### Calculate the sum of 1 plus 1

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# 1. Hello
# 2. Everyone

# %% [markdown]
# ---------------------

# %% [markdown]
# - this
# - is
# - _my_
# - ~~first~~
# - **Python**
# - Notebook

# %% [markdown]
# | Student | Grade |
# | ---   | ---  |
# | John Smith | 90 |
# | Jane Doe | 95 |

# %% [markdown]
# >*\"I should study more\"*  - John Smith
