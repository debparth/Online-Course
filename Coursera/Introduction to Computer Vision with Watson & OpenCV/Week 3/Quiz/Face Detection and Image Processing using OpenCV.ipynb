# %% [markdown]
# **Question 1:**
# Which of the following techniques or tools you can use to adjust improperly exposed images to become properly exposed images?

# %% [raw]
# Histogram Equalization

# %% [markdown]
# **Question 2:**
# Your local municipal government operates traffic cameras at key street intersections and highways. The cameras are placed at the top of tall light poles or other tall fixtures to maximize the view, but are not high enough in quality to read license plates. Which of the following tools and techniques would be the most appropriate to use to count the number of cars passing through the view of the camera?

# %% [raw]
# Background Subtraction

# %% [markdown]
# **Question 3:**
# The owner of a 24/7 parking lot near a busy concert hall currently has a rotating team of employees at $8/hour to distribute timestamped parking passes on entry, and collect payments of cars exiting the parking lot based on the time elapsed since the car entered the lot. Which of the following solutions below would you suggest to the owner to improve the efficiency of their business.

# %% [raw]
# OCR can be used to build a solution that reads license plate upon entry, which then get timestamped automatically and stored in a database, and reads the license plates again on the way out, to calculate the amount each driver owes the parking lot. Using an OCR based solution will yield maximum efficiency for the parking lot.

# %% [markdown]
# **Question 4:**
# True or False? If you set k=3 when running k-means clustering to quantize colours on an image, the resulting image will:

# %% [raw]
# Will reduce in unique colours to 3 unique colours.

# %% [markdown]
# **Question 5:**
# Multiple Choice: Which of the statements are True?

# %% [raw]
# OpenCV can be used to process video files and streaming video.
#
# You can check if an image is low in contrast by observing its histogram using OpenCV.

# %% [markdown]
# **Question 6:**
# How is the value of K in K-Means Clustering related to the file size of an image?

# %% [raw]
# The value of K is directly proportional to the file size

# %% [markdown]
# **Question 7:**
# What result would you see if you use a Face Cascade Classifier on the following picture?

# %% [markdown]
# ![image.jpg](attachment:image.jpg)

# %% [raw]
# The face classifier might or might not be able to detect a single face in the image. Further, it might detect certain regions as faces in the image even though they are not faces.

# %% [markdown]
# **Question 8:**
# How would the greyscale histogram of the following image look like?

# %% [markdown]
# ![image.jpg](attachment:image.jpg)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# General Classifier (also called Default Classifier), Speech Classifier, Food Classifier

# %% [markdown]
# **Question 9:**
# Which of the following image processing techniques can be used to improve the accuracy of Tesseract OCR for recognizing license plates? (Multiple Choice)

# %% [raw]
# Gaussian Blur
# Image resizing

# %% [markdown]
# **Question 10:**
# How does Colour Quantization reduce the number of unique colours in an image?

# %% [raw]
# Colour Quantization uses a technique called K Means Clustering to group pixels in images into K clusters. The value of K is typically < 256 to reduce the number of unique colours in an image
