# %% [markdown]
# **Question 1:**
# True or False: When importing OpenCV in Python3, you should use the code snippet:
#
# import cv3

# %% [raw]
# False

# %% [markdown]
# **Question 2:**
# How would the greyscale histogram of a completely white image look like?False

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Question 3:**
# We are given image that has 100 pixels in it. Each pixel in the image is comprised of 5 channels and each channel represents 16 = (2^4) colours. How much storage space is required for each pixel in the computer's memory?

# %% [raw]
# 20 bytes

# %% [markdown]
# **Question 4:**
# Which of the following symbol can be used before an openCV method to display it's help documentation?

# %% [raw]
# ?
