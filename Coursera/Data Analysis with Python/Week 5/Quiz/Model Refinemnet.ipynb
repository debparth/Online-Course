# %% [markdown]
# **Question 1:**
# What is the correct use of the "train_test_split" function such that 40% of the data samples will be utilized for testing, the parameter "random_state" is set to zero, and the input variables for the features and targets are x_data, y_data respectively?

# %% [raw]
# train_test_split(x_data, y_data, test_size=0.4, random_state=0)

# %% [markdown]
# **Question 2:**
# What is the correct use of the "train_test_split" function such that 40 samples will be utilized for testing, the parameter "random_state" is set to zero, and the input variables for the features and targets are x_data, y_data respectively?

# %% [raw]
# train_test_split(x_data, y_data, test_size=40, random_state=0)

# %% [markdown]
# **Question 3:**
# What is the output of the following code?
#
# cross_val_predict (lr2e, x_data, y_data, cv=3)

# %% [raw]
# The predicted values of the test data using cross-validation

# %% [markdown]
# **Question 4:**
# What dictionary value would we use to perform a grid search for the following values of alpha? 1,10, 100. No other parameter values should be tested

# %% [raw]
# [{'alpha': [1,10,100]}]

# %% [markdown]
# **Question 5:**
# You have a linear model; the average R^2 value on your training data is 0.5, you perform a 100th order polynomial transform on your data then use these values to train another model. After this step, your average R^2 is 0.99; which of the following comments is correct?

# %% [raw]
# The results on your training data is not the best indicator of how your model performs; you should use your test data to get a better idea

# %% [markdown]
# **Question 6:**
# Consider the following diagram of 4 fold cross-validation. From the diagram how many folds are used for training?

# %% [markdown]
# ![g2TIwDd9EeiHaBJdFW73Ag_b28fda6414b060b4210be1626ed06859_Screen-Shot-2018-04-03-at-4.26.13-PM.png](attachment:g2TIwDd9EeiHaBJdFW73Ag_b28fda6414b060b4210be1626ed06859_Screen-Shot-2018-04-03-at-4.26.13-PM.png)

# %% [raw]
# 3

# %% [markdown]
# **Question 7:**
# The following is an example of what?

# %% [markdown]
# ![SBkr8zeEEeissBKg1xWY5A_00227225a1f9f10045c83602ccef31e7_Screen-Shot-2018-04-03-at-5.17.08-PM.png](attachment:SBkr8zeEEeissBKg1xWY5A_00227225a1f9f10045c83602ccef31e7_Screen-Shot-2018-04-03-at-5.17.08-PM.png)

# %% [raw]
# Underfitting
