# %% [markdown]
# **Question 1:**
# If the predicted function is:

# %% [markdown]
# ![X-jhVTdXEeiTdwrluHC9aA_1c33ebc225b2ec12af4c21cc288c1912_Screen-Shot-2018-04-03-at-11.55.45-AM.png](attachment:X-jhVTdXEeiTdwrluHC9aA_1c33ebc225b2ec12af4c21cc288c1912_Screen-Shot-2018-04-03-at-11.55.45-AM.png)

# %% [raw]
# Multiple Linear Regression

# %% [markdown]
# **Question 2:**
# What is the maximum value of R^2 that can be obtained?

# %% [raw]
# 1

# %% [markdown]
# **Question 3:**
# We create a polynomial feature as follows "PolynomialFeatures(degree=2)"; what is the order of the polynomial?

# %% [raw]
# 2

# %% [markdown]
# **Question 4:**
# Which statement is true about Polynomial linear regression?

# %% [raw]
# Although the predictor variables of Polynomial linear regression are not linear the relationship between the parameters or coefficients is linear

# %% [markdown]
# **Question 5:**
# Consider the plot of one independent and one dependent variable. This is an example of what?

# %% [markdown]
# ![TySjQTdcEeinvxKfGmYdOg_c57dd678f7a1bdb52eb2b4f801e46335_Screen-Shot-2018-04-03-at-12.30.27-PM.png](attachment:TySjQTdcEeinvxKfGmYdOg_c57dd678f7a1bdb52eb2b4f801e46335_Screen-Shot-2018-04-03-at-12.30.27-PM.png)

# %% [raw]
# Polynomial Regression

# %% [markdown]
# **Question 6:**
# Consider the following equation:

# %% [markdown]
# ![mrc50jdfEeiKpA6ZQCE7wA_d5b99b98180e37f67b0659d10a8104f5_eq.png](attachment:mrc50jdfEeiKpA6ZQCE7wA_d5b99b98180e37f67b0659d10a8104f5_eq.png)

# %% [raw]
# The target or dependent variable
